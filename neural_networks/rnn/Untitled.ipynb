# %%
import numpy as np
data = open('input.txt', 'r').read()
data=data[1:]
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print ('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }
print(data)
print(char_to_ix,ix_to_char)
seq_length=25
# Out:
# data has 452 characters, 33 unique.
# Convolutional Neural Networks are very similar to ordinary Neural Networks from the previous chapter: they are made up of neurons that have learnable weights and biases. Each neuron receives some inputs, performs a dot product and optionally follows it with a non-linearity. The whole network still expresses a single differentiable score function: from the raw image pixels on one end to class scores at the other. And they still have a loss function.
# ...

# %%
x,y,result,x_train,y_train=[],[],[],[],[]
p=0

# %%
print(x,y)
len(data)
# Out:
# [] []
# 452

# %%
for i in range(len(data)-1):
    x.append(data[i])
    y.append(data[i+1])

# %%
from __future__ import print_function
from keras.models import Sequential
from keras import layers
import numpy as np
from six.moves import range

# %%
from keras.layers import Dense,LSTM

# %%
def encode(char):
    a=[]
    for i in range(len(char)):
        a.append(char_to_ix[char[i]])
    return a
def decode(char):
    b=[]
    for i in range(len(char)):
        b.append(ix_to_char[char[i]])
    return b

# %%
x_train=encode(x)
y_train=encode(y)
print(x_train,y_train)
# Out:
# [17, 27, 25, 8, 27, 7, 4, 26, 28, 27, 25, 6, 7, 30, 14, 12, 4, 24, 6, 7, 30, 14, 12, 26, 29, 27, 24, 0, 22, 30, 6, 24, 12, 30, 8, 12, 24, 2, 30, 22, 28, 10, 28, 7, 6, 24, 30, 26, 27, 30, 27, 24, 9, 28, 25, 6, 24, 2, 30, 14, 12, 4, 24, 6, 7, 30, 14, 12, 26, 29, 27, 24, 0, 22, 30, 19, 24, 27, 10, 30, 26, 11, 12, 30, 20, 24, 12, 8, 28, 27, 4, 22, 30, 3, 11, 6, 20, 26, 12, 24, 5, 30, 26, 11, 12, 2, 30, 6, 24, 12, 30, 10, 6, 9, 12, 30, 4, 20, 30, 27, 19, 30, 25, 12, 4, 24, 27, 25, 22, 30, 26, 11, 6, 26, 30, 11, 6, 8, 12, 30, 7, 12, 6, 24, 25, 6, 1, 7, 12, 30, 29, 12, 28, 13, 11, 26, 22, 30, 6, 25, 9, 30, 1, 28, 6, 22, 12, 22, 31, 30, 23, 6, 3, 11, 30, 25, 12, 4, 24, 27, 25, 30, 24, 12, 3, 12, 28, 8, 12, 22, 30, 22, 27, 10, 12, 30, 28, 25, 20, 4, 26, 22, 15, 30, 20, 12, 24, 19, 27, 24, 10, 22, 30, 6, 30, 9, 27, 26, 30, 20, 24, 27, 9, 4, 3, 26, 30, 6, 25, 9, 30, 27, 20, 26, 28, 27, 25, 6, 7, 7, 2, 30, 19, 27, 7, 7, 27, 29, 22, 30, 28, 26, 30, 29, 28, 26, 11, 30, 6, 30, 25, 27, 25, 18, 7, 28
# ...

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)
x_train=x_train.reshape(1,451,1)
y_train=y_train.reshape(1,451,1)
print(x_train,y_train)
# Out:
# [[[17]
#   [27]
#   [25]
#   [ 8]
#   [27]
#   [ 7]
#   [ 4]
#   [26]
#   [28]
#   [27]
#   [25]
#   [ 6]
#   [ 7]
#   [30]
#   [14]
#   [12]
#   [ 4]
#   [24]
#   [ 6]
#   [ 7]
#   [30]
#   [14]
#   [12]
#   [26]
#   [29]
#   [27]
#   [24]
#   [ 0]
#   [22]
#   [30]
#   [ 6]
#   [24]
#   [12]
#   [30]
#   [ 8]
#   [12]
#   [24]
#   [ 2]
#   [30]
#   [22]
#   [28]
#   [10]
#   [28]
#   [ 7]
#   [ 6]
#   [24]
#   [30]
#   [26]
#   [27]
#   [30]
#   [27]
#   [24]
#   [ 9]
#   [28]
#   [25]
#   [ 6]
#   [24]
#   [ 2]
#   [30]
#   [14]
#   [12]
#   [ 4]
#   [24]
#   [ 6]
#   [ 7]
#   [30]
#   [14]
#   [12]
#   [26]
#   [29]
#   [27]
#   [24]
#   [ 0]
#   [22]
#   [30]
#   [19]
#   [24]
#   [27]
#   [10]
#   [30]
#   [26]
#   [11]
#   [12]
#   [30]
#   [20]
#   [24]
#   [12]
#   [ 8]
#   [28]
#   [27]
#   [ 4]
#   [22]
#   [30]
#   [ 3]
#   [11]
#   [ 6]
#   [20]
#   [26]
#   [12]
#   [24]
#   [ 5]
#   [30]
#   [26]
#   [11]
#   [12]
#   [ 2]
#   [30]
#   [ 6]
#   [24]
#   [12]
#   [30]
# ...

# %%
model=Sequential()
model.add(LSTM(1, input_shape=(451,1), return_sequences=True))
model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_11 (LSTM)               (None, 451, 1)            12
# ...
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 6s 6s/step - loss: 423.8059
# Epoch 2/10
# 1/1 [==============================] - 1s 924ms/step - loss: 423.7648
# Epoch 3/10
# 1/1 [==============================] - 1s 917ms/step - loss: 423.7249
# Epoch 4/10
# 1/1 [==============================] - 1s 992ms/step - loss: 423.6864
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 423.6490
# Epoch 6/10
# 1/1 [==============================] - 1s 1s/step - loss: 423.6127
# Epoch 7/10
# 1/1 [==============================] - 1s 945ms/step - loss: 423.5772
# Epoch 8/10
# 1/1 [==============================] - 1s 916ms/step - loss: 423.5435
# Epoch 9/10
# 1/1 [==============================] - 1s 1s/step - loss: 423.5099
# Epoch 10/10
# 1/1 [==============================] - 1s 947ms/step - loss: 423.4779
